# %% [markdown]
# # SB-688 Interactive Walkthrough\nThis notebook demonstrates loading the kernel prompt and running simple dual-path verification.

# %%
from dual_path_verification import DualPathVerifier\nverifier = DualPathVerifier()\nverifier.run('Review a proposed policy change')
